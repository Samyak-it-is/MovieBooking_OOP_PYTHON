# %%
class movie:
    def film(self):
        print("\t\t\t\t\t Samyak Theatre Classes")
        print("\t\t\t\t From Real To Reel...Take The Feel")
        return("\t\t\t\t\t Movies in Theatre Right Now:")
    def genre(rp):
        x=["Horror","Comedy","Thriller","Emotional"]
        for k in x:
            print("\n\n",k)
    def horror(self):
        x=["BulBul","Evil_Returns","Dead_Evil_Rise","Horrority"]
        y=[200,200,200,200]
        horror_={"Movies":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(horror_)
        print("\n\n Horror_Movies\n\n")
        print(df)
        while x:
            x==True
            b=int(input("Enter the position:\t"))
            c=int(input("Enter the number of tickets:\t"))
            z=horror_["Price"][b]
            y=z*c
            d=[]
            d.append(y)
            x=input("Are you sure you want to proceed towards the payment ?\n Write yes if you are sure")
            if (x=="yes"):
                print("Thank You For Booking The Tickets")
                break
        t=sum(d)
        m=(sum(d)*0.05*0.05)
        k=t+m
        import colorama
        from colorama import Fore,Back,Style
        print("Service_Tax = 5%")
        print("Convinience_Fee= 5%")
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"Total Amount :",t,"Rupees")
    def comedy(self):
        x=["Bhul Bhulliya","Phir Hera Pheri","Friends","Hello Brother"]
        y=[250,250,250,250]
        comedy_={"Movies":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(comedy_)
        print("\n\n Comedy_Movies\n\n")
        print(df)
        while x:
            x==True
            b=int(input("Enter the position:\t"))
            c=int(input("Enter the number of tickets:\t"))
            z=comedy_["Price"][b]
            y=z*c
            d=[]
            d.append(y)
            x=input("Are you sure you want to proceed towards the payment ?\n Write yes if you are sure")
            if (x=="yes"):
                print("Thank You For Booking The Tickets")
                break
        t=sum(d)
        m=(sum(d)*0.05*0.05)
        k=t+m
        import colorama
        from colorama import Fore,Back,Style
        print("Service_Tax = 5%")
        print("Convinience_Fee= 5%")
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"Total Amount :",t,"Rupees")
    def thriller(self):
        x=["Pathaan","Freddy","Mission Majnu","Fall"]
        y=[150,150,150,150]
        thriller_={"Movies":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(thriller_)
        print("\n\n Thriller_Movies\n\n")
        print(df)
        while x:
            x==True
            b=int(input("Enter the position:\t"))
            c=int(input("Enter the number of tickets:\t"))
            z=thriller_["Price"][b]
            y=z*c
            d=[]
            d.append(y)
            x=input("Are you sure you want to proceed towards the payment ?\n Write yes if you are sure")
            if (x=="yes"):
                print("Thank You For Booking The Tickets")
                break
        t=sum(d)
        m=(sum(d)*0.05*0.05)
        k=t+m
        import colorama
        from colorama import Fore,Back,Style
        print("Service_Tax = 5%")
        print("Convinience_Fee= 5%")
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"Total Amount :",t,"Rupees")
    def emotional(self):
        x=["Inside Out","The Fault In Our Stars","Forrest Gump","The Notebook"]
        y=[270,270,270,270]
        emotional_={"Movies":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(emotional_)
        print("\n\n Emotional_Movies\n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the position:\t"))
            c=int(input("Enter the number of tickets:\t"))
            z=emotional_["Price"][b]
            y=z*c
            d.append(y)
            x=input("Are you sure you want to proceed towards the payment ?\n Write yes if you are sure")
            if (x=="yes"):
                print("Thank You For Booking The Tickets")
                break
        t=sum(d)
        m=(sum(d)*0.05*0.05)
        k=t+m
        import colorama
        from colorama import Fore,Back,Style
        print("Service_Tax = 5%")
        print("Convinience_Fee= 5%")
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"Total Amount :",t,"Rupees")
obj=movie()
print(obj.film())
print(obj.genre())
x=input("Enter the Movie Genre you want to Book Tickets For:\t")
if x=="Horror":
    print(obj.horror())
elif x=="Comedy":
    print(obj.comedy())
elif x=="Thriller":
    print(obj.thriller())
elif x=="Emotional":
    print(obj.emotional())
else:
    print("Enter the correct Genre Of Movie")
# Out:
# 					 Samyak Theatre Classes
# 				 From Real To Reel...Take The Feel
# 					 Movies in Theatre Right Now:
#
#
#  Horror
#
#
#  Comedy
#
#
#  Thriller
#
#
#  Emotional
# None
# Enter the Movie Genre you want to Book Tickets For:	Horror
#
#
#  Horror_Movies
#
#
#            Movies  Price
# 0          BulBul    200
# 1    Evil_Returns    200
# 2  Dead_Evil_Rise    200
# 3       Horrority    200
# Enter the position:	0
# Enter the number of tickets:	2
# Are you sure you want to proceed towards the payment ?
#  Write yes if you are sureihbdv
# Enter the position:	2
# Enter the number of tickets:	4
# Are you sure you want to proceed towards the payment ?
#  Write yes if you are sureyes
# Thank You For Booking The Tickets
# Service_Tax = 5%
# Convinience_Fee= 5%
# Total Amount : 800 Rupees
# None
